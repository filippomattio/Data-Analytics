# %% [markdown]
# <h1>Sources of data</h1>
# <li><b>local files</b>csv, xls, txt, pdf</li>
# <li><b>database servers</b>
# <ul>
# <li>Relational databases
# <li>NoSQL databases
# </ul>
# <li><b>On the web</b>
# <ul>
# <li>html
# <li>JSON
# <li>XML
# </ul>

# %% [markdown]
# <h2>Getting Data</h2>
# <li>Internet (Server)</li>
# <li>Web Scraping --> "copy & paste" from web browser on a webpage. html: way webpage was encoded for human being to see it in a polite way: it is a markup language</li>
# <li>API: much easier. I can go to the server and talk with him, and he just sends me what I need. Most websites don't have an API</li>
# <li>Database</li>

# %% [markdown]
# <h2>Getting data from the Internet</h2>
# <li>Accessing the data is through APIs or web scraping
# <li>Data usually arrives in either JSON, XML or HTML
# <li>Python has libraries to help getting the data as well as extracting "useful" data

# %% [markdown]
# <h2>Data Exchange through Internet</h2>
# <p>I cannot just ask objects, I have to flatten those into a string representation; take the string and convert it into bytes;; once I have all those bytes I need to take those and convert back into that string representation</p>
# <ol>
#     <li><b>Serialization</b>: take data and convert those into strings</li>
#     <li><b>Encoding</b>: encode the string into bytes --> ASCII/Unicode </li>
#     <li><b>Decoding</b>: decode the byte into string</li>
#     <li><b>Deserialize</b>: take that string and convert into python object</li>
# </ol>

# %% [markdown]
# <h2>The <i>requests</i> library</h2>
# <li>The primary mechanism for sending an API request or accessing a web server

# %%
#Way to access to database:
# - Access to Database given by Database administrator through an API: application programming interface
# - Web scraping --> 1. Get html page 2. Parse the html - Done with requests library in Python: 
#response = requests.get(url) : HTTPResponse object. HTTP: protocol of the web
#HTTPRequest: GET, PUT, POST (update, not renew always), DELETE

# %%
j = 0
m = 1
n = -1
x = 2.5
y = 0.0
result = not x or not n or m+n
result
# Out:
# 0

# %% [markdown]
# <h3>Step 1: Import the requests library</h3>

# %%
import requests

# %% [markdown]
# <h3>Step 2: Send an HTTP request, get the response, and save in a variable</h3>
# <p>On the web everyone speaks the same language: HTTP --> to speak with the web you have to ask for an HTTP request</p>
# <p>Simplest request: GET --> you need the URL: unified resource location</p>

# %%
response = requests.get("http://www.epicurious.com/search/Tofu+Chili") #+ due to you can't put space

# %%
response.encoding
#Why encoding? On Internet only bytes are transferred! String --> Encode --> Bytes --> Decode --> String
# With n bits you can encode 2 elevated to n characters
#first ASCII 8 bits: 256 characters
#second ASCII 16 bits: 2 alla 16
#third ASCII 32 bits: 2 alla 32 to cover all the languages
#Backward Compatibility: first and second ASCII are in conflicts: ex. char A:
#UTF - 8: variable lenght encoding: you can send both 8 bits and 16 bits
# Out:
# 'utf-8'

# %% [markdown]
# <h3>Step 3: Check the response status code to see if everything went as planned!!!</h3>
# <li>status code 200: the request response cycle was successful
# <li>any other status code: it didn't work as expected (e.g., 404 = page not found)</li>

# %%
print(response.status_code) #200: everything was OK
#1st thing to do!! GET request can not be completed :
# - Server down
# - URL not valid
# Out:
# 200

# %%
response.content #a bunch of bytes: I have to know how to decode it!
#b' stays for bytes
# Out:
# b'<!doctype html>\n<html>\n  <head><meta charset="utf-8">\n<meta name="apple-itunes-app" content="app-id=312101965" />\n<title>Search | Epicurious.com</title>\n<link rel="dns-prefetch" href="//assets.adobedtm.com">\n<link rel="dns-prefetch" href="https://www.google-analytics.com">\n<link rel="dns-prefetch" href="//tpc.googlesyndication.com">\n<link rel="dns-prefetch" href="//static.parsely.com">\n<link rel="dns-prefetch" href="//condenast.demdex.net">\n<link rel="dns-prefetch" href="//capture.condenastdigital.com">\n<link rel="dns-prefetch" href="//pixel.condenastdigital.com">\n<link rel="dns-prefetch" href="//use.typekit.net">\n<link rel="dns-prefetch" href="//fonts.typekit.net">\n<link rel="dns-prefetch" href="//p.typekit.net">\n<link rel="dns-prefetch" href="//assets.epicurious.com">\n<link rel="dns-prefetch" href="//ad.doubleclick.net">\n<link rel="dns-prefetch" href="//pagead2.googlesyndication.com">\n<link rel="dns-prefetch" href="//z.moatads.com">\n\n<meta content="en_US" property="og:locale" itemprop="inLanguage" />\n<meta http-equiv="x-ua-compatible" content="IE=edge" />\n\n<meta http-equiv="cache-control" content="no-cache" />\n<meta http-equiv="pragma" content="no-cache" />\n\n<meta itemprop="name" content="Search | Epicurious.com" />\n<meta itemprop="logo" content="https://www.epicurious.com/static/img/misc/epicurious-social-logo.png" />\n\n<meta name="description" content="Easily search and browse more than 37,000 recipes, articles, galleries, menus, and videos from Epicurious.com, Bon App\xc3\xa9tit, and other partners." />\n    <meta itemprop="author" content="Epicurious" />\n\n\n<link rel="canonical" href="https://www.epicurious.com/search/Tofu%2BChili" />\n\n<meta name="copyright" content="Copyright (c) 2022 Conde Nast" />\n<meta name="p:domain_verify" content="9c2002da922784afad64b638161c75f7" />\n\n\n<meta property="og:title" content="Search | Epicurious.com" />\n<meta property="og:type" content="website" />\n<meta property="og:url" content="https://www.epicurious.com/search/Tofu%2BChili" /><meta property="og:description" content="Easily search and browse more than 37,000 recipes, articles, galleries, menus, and videos from Epicurious.com, Bon App\xc3\xa9tit, and other partners." />\n<meta property="og:image" content="https://www.epicurious.com/static/img/misc/epicurious-social-logo.png" />\n<meta property="og:site_name" content="Epicurious"/>\n<meta property="fb:app_id" content="1636080783276430" />\n<meta property="fb:admins" content="722582662"/>\n<meta property="fb:admins" content="774348857"/>\n<meta property="fb:admins" content="596666898"/>\n<meta property="fb:admins" content="837402"/>\n<meta property="fb:admins" content="685417657"/>\n<meta property="fb:admins" content="22500087"/>\n<meta property="fb:admins" content="1107036618"/>\n<meta property="fb:admins" content="1045857449"/>\n<meta property="fb:admins" content="14601235"/>\n\n<link rel="publisher" href="https://plus.google.com/106968200752753566855"/>\n\n<link rel="icon" type="image/png" href="/static/img/favicon.png" />\n<meta name="theme-color" content="#f93f23" />\n\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\n<!-- metadataTags end -->\n<script>\n    var EPI = EPI || {\n        barCnsCrtPage: false,\n        onCompleteActions: []\n    };\n\n    document.onreadystatechange = function () {\n        if (document.readyState === \'complete\') {\n            EPI.onCompleteActions.forEach(function (callback) {\n                if (typeof callback === \'function\') {\n                    callback();\n                }\n            });\n\n            if (window.location.search.substr(1).indexOf(\'ui-regression-test=true\') >= 0) {\n                console.log(\'ui-regression-test-ready\');\n            }\n        }\n    };\n\n    <!-- https://github.com/filamentgroup/loadJS -->\n    !function(a){var b=function(b,c){"use strict";var d=a.document.getElementsByTagName("script")[0],e=a.document.createElement("script");retu ...

# %% [markdown]
# <h3>WWW data is usually encoded</h3>
# <li>The b' in front of the response content indicates an encoded byte string
# <li>The <meta charset="utf-8"> indicates that the page is using "utf-8" encoding
# <li>utf-8 == <i>Unicode</i> variable length character encoding system
# <li>Data received from the world wide web is usually in utf-8
# <li>Python strings are "plain" (unencoded) character sequences
# <li><b>Corollary!</b> We need to convert the utf-8 string into a python str

# %% [markdown]
# <a href="http://www.diveintopython3.net/strings.html">Click here!</a> if you want to know all about strings and character encoding

# %%
print(type(response.content))
print(type(response.content.decode('utf-8')))
# Out:
# <class 'bytes'>
# <class 'str'>

# %%
response.encoding
# Out:
# 'utf-8'

# %% [markdown]
# <h3>Step 4: Get the content of the response</h3>
# <li>Convert to utf-8 if necessary

# %%
type(response.content.decode('utf-8'))
# Out:
# str

# %% [markdown]
# <h3>In-class problem</h3>
# <li>Get the contents of Wikipedia's main page and look for the string "Did you know" in it
# <li>At what location is it on the page?

# %%
url = "https://en.wikipedia.org/wiki/main_page"
#Server databases contain Objects, with reference to other objects maybe: how can you do?
#1) Flatten the object and transform it in Strings --> Serialize the object to create a string form of the object. Done by the server
# The string is encoded --> Bytes that then are decoded to get the String --> They are then deserialized to get the Object
#We do it with JSON
#The rest of your code should go below this line
#import

# %% [markdown]
# <h1>JSON: JavaScript Object Notation--> Used with APIs</h1>
#
# <li>Standard for "serializing" data objects for storage or transmission: take any object and convert into a string
# <li>Human-readable, useful for data interchange
# <li>Also useful for representing and storing semistructured data
# <li>Stored as plain (byte strings or utf-8 strings) text
# <li>Contains data type information

# %% [markdown]
# <h2>json</h2>
# <li>The python library - json - deals with converting text to and from JSON

# %% [markdown]
# <h2>Python and JSON data types</h2>
# <table align="left">
# <tr><td>JSON</td><td>Python</td></tr>
# <tr><td>number</td>	<td>int,float</td></tr>
# <tr><td>string</td>	<td>str</td></tr>
# <tr><td>Null</td>	<td>None</td></tr>
# <tr><td>true/false</td>	<td>True/False</td></tr>
# <tr><td>Object</td>	<td>dict</td></tr>
# <tr><td>Array</td>	<td>list</td></tr>
# </table>

# %% [markdown]
# <b>json.loads converts a json object into a python data object</b>

# %%
import json
data_string = '[{"b": [2, 4], "3.0": "c", "a": "A"},34]' #NB: JSON dictionary only accepts strings as key! -->not such a limitation
#data_string = '[{"b": [2, 4], 3: "c", "a": "A"},34]' -->ERROR!!!
#a JSON string: need to be deserialized to get the object
python_data = json.loads(data_string) 
print(type(python_data))
print(python_data[0])
print(type(python_data[0]))
# data_string
# print(type(python_data))
# Out:
# <class 'list'>
# {'b': [2, 4], '3.0': 'c', 'a': 'A'}
# <class 'dict'>

# %% [markdown]
# <h3>json.loads recursively decodes a string in JSON format into equivalent python objects</h3>
# <li>data_string's outermost element is converted into a python list (in the example!)
# <li>the first element of that list is converted into a dictionary
# <li>the key of that dictionary is converted into a string
# <li>the value of that dictionary is converted into a list of two integer elements

# %%
print(type(data_string),type(python_data))
print(type(python_data[0]),python_data[0])
print(type(python_data[0]['b']),python_data[0]['b'])
# Out:
# <class 'str'> <class 'list'>
# <class 'dict'> {'b': [2, 4], '3.0': 'c', 'a': 'A'}
# <class 'list'> [2, 4]

# %%
python_data[0]['b'][0]
# Out:
# 2

# %% [markdown]
# <h3>json.loads will throw an exception if the format is incorrect</h3>

# %%
#Correct
json.loads('"Hello"')


#Wrong. WHY?
json.loads("Hello")
# Out:
# 'Hello'

# %% [markdown]
# <h3>json.dumps creates a json string from a python data object</h3>

# %%
import json
data_string = json.dumps(python_data) #convert a series of Python Object and you serialize in in a Json
print(type(data_string))
print(data_string)
data_string
# Out:
# <class 'str'>
# [{"b": [2, 4], "3.0": "c", "a": "A"}, 34]
# '[{"b": [2, 4], "3.0": "c", "a": "A"}, 34]'

# %% [markdown]
# <h1>API: Application Programming Interface</h1>
# <li>A protocal containing a set of commands or functions that allow one piece of software  to talk to another
# <li>Data from the web is often gotten through an API
# <li>Web APIs usually consist of two parts:
# <ul>
# <li><b>request</b> an well-formed HTTP request to a server
# <li><b>response</b> a response from the server, usually either an html page or a JSON object
# </ul>

# %% [markdown]
# <h2>The HTTP request</h2>
# <li>Contains a url
# <li>Contains a set of parameters required by the server to figure out what data to send back
# <li>Often, a parameter is a unique <b>access key</b> that the server uses to keep track of who is requesting the data

# %% [markdown]
# <h1>API example: Google Geocoding API</h1>
# <h2>NB USE LIONMAIL ACCOUNT!! SE NO DEVO PAGARE 50$</h2>
# <li><a href="https://developers.google.com/maps/documentation/geocoding/start">Documentation</a>
# <li>Google has a large number of map and location related APIs
# <li>You need an account and an API key to use these APIs
# <li>To set up an account and get a key:
# <ul>
# <li>go to <a href="https://cloud.google.com/">google cloud</a>
# <li>click "go to console" or "try gcp for free"
# <li>if creating a new account, enter all details
# <li>go to API and services
# <li>click "Enable APIs" and search for geocoding api
# <li>click on credentials and create an API key

# %% [markdown]
# <h2>requests library and API requests</h2>

# %%
#My api_key
with open("/home/uday/Documents/Columbia_University/API_Keys/geocoding_key.txt",'r') as f:
    api_key = f.read().strip() #to remove final and initial spaces

# %%
address="Columbia University, New York, NY"
address=address.replace(' ','_') #no spaces
#api_key=""
url="https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (address,api_key) #json?: I want the response in json
response = requests.get(url)
response.json()
# Out:
# <class 'requests.models.Response'>

# %%
response.encoding #to verify the response is coded in utf8
# Out:
# 'UTF-8'

# %% [markdown]
# <h4>requests can automatically decode and convert a json response into a python object

# %%
response.json() #2 keys: 'results' and 'status'
# Out:
# {'results': [{'address_components': [{'long_name': 'New York',
#      'short_name': 'New York',
#      'types': ['locality', 'political']},
#     {'long_name': 'Manhattan',
#      'short_name': 'Manhattan',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'New York County',
#      'short_name': 'New York County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '10027', 'short_name': '10027', 'types': ['postal_code']}],
#    'formatted_address': 'New York, NY 10027, USA',
#    'geometry': {'location': {'lat': 40.8075355, 'lng': -73.9625727},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 40.8088844802915,
#       'lng': -73.96122371970849},
#      'southwest': {'lat': 40.8061865197085, 'lng': -73.9639216802915}}},
#    'place_id': 'ChIJyQ3Tlj72wokRUCflR_kzeVc',
#    'plus_code': {'compound_code': 'R25P+2X New York, NY, USA',
#     'global_code': '87G8R25P+2X'},
#    'types': ['establishment', 'point_of_interest', 'university']}],
#  'status': 'OK'}

# %% [markdown]
# <h3>Exception checking!</h3>
# <li>Ideally, we should always check if the data grab has been successful
# <li>Especially if we are incorporating our results into a "live" analysis

# %%
response_data = ''
address="Columbia University, New York, NY"
url="https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s" % (address,api_key)
try:
    response = requests.get(url)
    if not response.status_code == 200:
        print("HTTP error",response.status_code)
    else:
        try:
            response_data = response.json()
        except:
            print("Response not in valid JSON format")
except:
    print("Something went wrong with requests.get")
print(type(response_data))
print(response_data)
# Out:
# <class 'dict'>
# {'results': [{'address_components': [{'long_name': 'New York', 'short_name': 'New York', 'types': ['locality', 'political']}, {'long_name': 'Manhattan', 'short_name': 'Manhattan', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'New York County', 'short_name': 'New York County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10027', 'short_name': '10027', 'types': ['postal_code']}], 'formatted_address': 'New York, NY 10027, USA', 'geometry': {'location': {'lat': 40.8075355, 'lng': -73.9625727}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 40.8088844802915, 'lng': -73.96122371970849}, 'southwest': {'lat': 40.8061865197085, 'lng': -73.9639216802915}}}, 'place_id': 'ChIJyQ3Tlj72wokRUCflR_kzeVc', 'plus_code': {'compound_code': 'R25P+2X New York, NY, USA', 'global_code': '87G8R25P+2X'}, 'types': ['establishment', 'point_of_interest', 'university']}], 'status': 'OK'}

# %% [markdown]
# <b>Try this</b>: Write a function that takes an address as an argument and returns a (latitude, longitude) tuple</h2>

# %%
# def get_lat_lng(address_string,api_key):

#     return (lat,lng)
    
# get_lat_lng("Columbia University",api_key)

# %%
# get_lat_lng("London Business School",api_key)

# %%
# get_lat_lng("Monash University",api_key)

# %% [markdown]
# <h1>XML --> Used with APIs</h1>
# <li>eXtensible Markup Language
# <li>data is stored in a tree
# <li>data items are "tagged" with named values
# <li>html is (loosely) similar to XML (both are based on SGML)
# <li>The python library - lxml - deals with converting an xml string to python objects and vice versa</li>

# %%
data_string = """
<Bookstore>
   <Book ISBN="ISBN-13:978-1599620787" Price="15.23" Weight="1.5">
      <Title>New York Deco</Title>
      <Authors>
         <Author Residence="New York City">
            <First_Name>Richard</First_Name>
            <Last_Name>Berenholtz</Last_Name>
         </Author>
      </Authors>
   </Book>
   <Book ISBN="ISBN-13:978-1579128562" Price="15.80">
      <Remark>
      Five Hundred Buildings of New York and over one million other books are available for Amazon Kindle.
      </Remark>
      <Title>Five Hundred Buildings of New York</Title>
      <Authors>
         <Author Residence="Beijing">
            <First_Name>Bill</First_Name>
            <Last_Name>Harris</Last_Name>
         </Author>
         <Author Residence="New York City">
            <First_Name>Jorg</First_Name>
            <Last_Name>Brockmann</Last_Name>
         </Author>
      </Authors>
   </Book>
</Bookstore>
"""

# %%
from lxml import etree
root = etree.XML(data_string)
# print(root.tag,type(root.tag))
root
# Out:
# <Element Bookstore at 0x7fea10d518c0>

# %% [markdown]
# <h4>XML trees are stored as utf-8 byte strings</h4>

# %%
print(etree.tostring(root, pretty_print=True))
# Out:
# b'<Bookstore>\n   <Book ISBN="ISBN-13:978-1599620787" Price="15.23" Weight="1.5">\n      <Title>New York Deco</Title>\n      <Authors>\n         <Author Residence="New York City">\n            <First_Name>Richard</First_Name>\n            <Last_Name>Berenholtz</Last_Name>\n         </Author>\n      </Authors>\n   </Book>\n   <Book ISBN="ISBN-13:978-1579128562" Price="15.80">\n      <Remark>\n      Five Hundred Buildings of New York and over one million other books are available for Amazon Kindle.\n      </Remark>\n      <Title>Five Hundred Buildings of New York</Title>\n      <Authors>\n         <Author Residence="Beijing">\n            <First_Name>Bill</First_Name>\n            <Last_Name>Harris</Last_Name>\n         </Author>\n         <Author Residence="New York City">\n            <First_Name>Jorg</First_Name>\n            <Last_Name>Brockmann</Last_Name>\n         </Author>\n      </Authors>\n   </Book>\n</Bookstore>\n'

# %%
print(etree.tostring(root, pretty_print=True).decode("utf-8"))
# Out:
# <Bookstore>
#    <Book ISBN="ISBN-13:978-1599620787" Price="15.23" Weight="1.5">
#       <Title>New York Deco</Title>
#       <Authors>
#          <Author Residence="New York City">
#             <First_Name>Richard</First_Name>
#             <Last_Name>Berenholtz</Last_Name>
#          </Author>
#       </Authors>
#    </Book>
#    <Book ISBN="ISBN-13:978-1579128562" Price="15.80">
#       <Remark>
#       Five Hundred Buildings of New York and over one million other books are available for Amazon Kindle.
#       </Remark>
#       <Title>Five Hundred Buildings of New York</Title>
#       <Authors>
#          <Author Residence="Beijing">
#             <First_Name>Bill</First_Name>
#             <Last_Name>Harris</Last_Name>
#          </Author>
#          <Author Residence="New York City">
#             <First_Name>Jorg</First_Name>
#             <Last_Name>Brockmann</Last_Name>
#          </Author>
#       </Authors>
#    </Book>
# </Bookstore>

# %% [markdown]
# <h3>Iterating over an XML tree</h3>
# <li>Use an iterator.
# <li>The iterator will generate every tree element for a given subtree

# %%
for element in root.iter():
    print(element)
# Out:
# <Element Bookstore at 0x7fea10d518c0>
# <Element Book at 0x7fea1105cc40>
# <Element Title at 0x7fea1105cfc0>
# <Element Authors at 0x7fea1105c780>
# <Element Author at 0x7fea1105cc40>
# <Element First_Name at 0x7fea1105cfc0>
# <Element Last_Name at 0x7fea1105c780>
# <Element Book at 0x7fea1105cc40>
# <Element Remark at 0x7fea1105cfc0>
# <Element Title at 0x7fea1105c780>
# <Element Authors at 0x7fea1105cc40>
# <Element Author at 0x7fea1105cfc0>
# <Element First_Name at 0x7fea1105c780>
# <Element Last_Name at 0x7fea1105cc40>
# <Element Author at 0x7fea1105cfc0>
# <Element First_Name at 0x7fea1105c780>
# <Element Last_Name at 0x7fea1105cc40>

# %% [markdown]
# <h4>Or just use the child in subtree construction

# %%
for child in root:
    for thing in child:
        print(thing)
# Out:
# <Element Title at 0x7fea1105e380>
# <Element Authors at 0x7fea1105e440>
# <Element Remark at 0x7fea1105e400>
# <Element Title at 0x7fea1105e380>
# <Element Authors at 0x7fea1105e440>

# %% [markdown]
# <h4>Accessing the tag</h4>

# %%
for child in root:
    print(child.tag)
# Out:
# Book
# Book

# %% [markdown]
# <h4>Using the iterator to get specific tags<h4>
# <li>In the below example, only the author tags are accessed
# <li>For each author tag, the .find function accesses the First_Name and Last_Name tags
# <li>The .find function only looks at the children, not other descendants, so be careful!
# <li>The .text attribute prints the text in a leaf node

# %%
for element in root.iter("Author"):
    print(element)
    print(element.find('First_Name').text,element.find('Last_Name').text)
    
    #.text!!!!
# Out:
# <Element Author at 0x7fea11064140>
# Richard Berenholtz
# <Element Author at 0x7fea11064040>
# Bill Harris
# <Element Author at 0x7fea110641c0>
# Jorg Brockmann

# %%
#another way to find elements
for element in root.findall('Book/Authors/Author/First_Name'):
    print(element.text)
# Out:
# Richard
# Bill
# Jorg

# %% [markdown]
# <h4>Problem: Find the last names of all authors in the tree “root” using xpath</h4>

# %%
for element in root.findall('Book/Authors/Author/Last_Name'):
    print(element.text)
# Out:
# Berenholtz
# Harris
# Brockmann

# %% [markdown]
# <h4>Using values of attributes as filters</h4>
# <li>Example: Find the first name of the author of a book that weighs 1.5 oz

# %%
root.find('Book[@Weight="1.5"]/Authors/Author/First_Name').text #look for an attribute inside the book tag
# Out:
# 'Richard'

# %% [markdown]
# <b>Try This</b>: Print first and last names of all authors who live in New York City
