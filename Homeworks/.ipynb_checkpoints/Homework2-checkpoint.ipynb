# %%
from time import sleep 
from random import random

# %%
def get_businesses(query,api_key,min_rating=0.0,max_results = 30) :
    query = query.replace(' ','_')
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
    new_url = url + 'query=' + query + '&key=' + api_key
    try:
        response = requests.get(new_url)
        if not response.status_code == 200:
            print("HTTP error",response.status_code)
        else:
            try:
                x = response.json()
            except:
                print("Response not in valid JSON format")
    except:
        print("Something went wrong with requests.get")
    
    y = x['results']
    l = []
    
    for i in y:
        rating = i['rating']
        if rating >= min_rating:
            name = i['name']
            address = i['formatted_address']
            open_now = i['opening_hours']
            price_level = i.get('price_level')
            new = (name,address, open_now, price_level, rating)
            l.append(new)
            if len(l)==max_results:
                return l
    
    while x.get('next_page_token')!=None:
        new_url = url + 'key=' + api_key + "&pagetoken=" + x['next_page_token']
        #print(new_url)
        response = requests.get(new_url) 
        
        while response.json().get('status') != 'OK':  
            sleep(random()) 
            response = requests.get(new_url) 
            
        x = response.json()
        #print(x)
        y = x['results']
        
        for i in y:
            rating = i['rating']
            if rating >= min_rating:
                name = i['name']
                address = i['formatted_address']
                open_now = i['opening_hours']
                price_level = i.get('price_level')
                new = (name,address, open_now, price_level, rating)
                l.append(new)
                if len(l)==max_results:
                    return l
    return l

# %%
api_key = 'AIzaSyAiXuCofGIyFv1A1WT3cQLIbBCUUlFUsUc'
get_businesses("restaurants near Columbia University", api_key, 0, 50)
# Out:
# [('DIG',
#   '2884 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   4.1),
#  ('Pisticci',
#   '125 La Salle St, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.5),
#  ('Toast Uptown',
#   '3157 Broadway, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Elysian Fields',
#   '1207 Amsterdam Ave, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Le Monde',
#   '2885 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.1),
#  ('Five Guys',
#   '2847 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Shake Shack Morningside Heights',
#   '2957 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   3.6),
#  ('Symposium',
#   '544 W 113th St, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Junzi Kitchen - Morningside Heights',
#   '2896 Broadway, Manhattan, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('314',
#   '3143 Broadway, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.7),
#  ('El Porton',
#   '3151 Broadway, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ("Mel's Burger Bar",
#   '2850 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Community Food & Juice',
#   '2893 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Chapati House',
#   '3153 Broadway, New York, NY 10027, United States',
#   {'open_now': True},
#   1,
#   4.4),
#  ('Sido Grill',
#   '2288 Frederick Douglass Blvd, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Dos Toros',
#   '2911 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   2.5),
#  ('Chipotle Mexican Grill',
#   '2843 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   4),
#  ('Nikko',
#   '1280 Amsterdam Ave, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Max Soha',
#   '1274 Amsterdam Ave, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.5),
#  ('Massawa',
#   '1239 Amsterdam Ave, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.5),
#  ('Tartina',
#   '1034 Amsterdam Ave, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Famous Famiglia',
#   '2859 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   4.1),
#  ('Harlem Shake',
#   '100 W 124th St, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Trufa Pizzeria',
#   '3161 Broadway, New York, NY 10027, United States',
#   {'open_now': True},
#   1,
#   3.8),
#  ('The Heights Bar & Grill',
#   '2867 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Peking Garden',
#   '3163 Broadway #3, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   3.9),
#  ("Tom's",
#   '2880 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   4.1),
#  ('Pret A Manger',
#   '2955 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   3.5),
#  ('Jin Ramen West Harlem',
#   '3183 Broadway, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.4),
#  ('Angel of Harlem',
#   '2272 Frederick Douglass Blvd, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Crepes On Columbus',
#   '990 Columbus Ave, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Sapps',
#   '2888 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   None,
#   4.2),
#  ('The Calaveras NYC',
#   '949 Columbus Ave, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   4.7),
#  ('BLVD Bistro NY',
#   '2149 Frederick Douglass Blvd, New York, NY 10026, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Harlem Biscuit Company',
#   '2099 Frederick Douglass Blvd, New York, NY 10026, United States',
#   {'open_now': True},
#   None,
#   4.5),
#  ('La Salle Dumpling Room',
#   '3141 Broadway, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('The Ellington',
#   '2745 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.3),
#  ('Row House',
#   '2128 Frederick Douglass Blvd, New York, NY 10026, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Marlow Bistro',
#   '1018 Amsterdam Ave, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.4),
#  ('SheShe Pizzeria',
#   '961 Columbus Ave, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   4.3),
#  ('Checkers',
#   '291 St Nicholas Ave, New York, NY 10027, United States',
#   {'open_now': True},
#   1,
#   3.7),
#  ('Cantina Taqueria & Tequila Bar',
#   '2099 Frederick Douglass Blvd, New York, NY 10026, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Dinosaur Bar-B-Que',
#   '700 W 125th St, New York, NY 10027, United States',
#   {'open_now': True},
#   2,
#   4.4),
#  ('Cafe Du Soleil',
#   '2723 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   2,
#   4.2),
#  ('Subs Conscious',
#   '1213 Amsterdam Ave, New York, NY 10027, United States',
#   {'open_now': True},
#   1,
#   3.8),
#  ('El Tina Harlem Restaurant',
#   '511 W 125th St, New York, NY 10027, United States',
#   {'open_now': True},
#   1,
#   4.3),
#  ('Panda Express',
#   '2852 Broadway, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   3.8),
#  ('West Place',
#   '1288 Amsterdam Ave #4225, New York, NY 10027, United States',
#   {'open_now': True},
#   1,
#   3.6),
#  ('Hamilton Deli',
#   '1129 Amsterdam Ave, New York, NY 10025, United States',
#   {'open_now': True},
#   1,
#   4),
#  ('Harlem Burger Co.',
#   '2190 Frederick Douglass Blvd, New York, NY 10026, United States',
#   {'open_now': True},
#   2,
#   3.9)]
